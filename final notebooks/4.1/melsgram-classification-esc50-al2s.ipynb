# %% [markdown]
# # Architectures with Mel Spectrogram as Input
# ## Audio Classification with the ESC-50 dataset
#
# This notebook performs audio classification on audio fragments of 2 seconds long
#
# The project starts with variables extracted from a checkpoint in 6.1 ESC50 - al5s

# %%
# IMPORT ALL LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import random
import seaborn as sns

import IPython.display as ipd
import librosa
import librosa.display

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.layers import Layer, Dense
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Load the ESC-50 data from previous checkpoint

# %%
# List of labels in the order they appear
labels = [
    'dog',
    'glass_breaking',
    'drinking_sipping',
    'rain',
    'insects',
    'laughing',
    'hen',
    'engine',
    'breathing',
    'crying_baby',
    'hand_saw',
    'coughing',
    'snoring',
    'chirping_birds',
    'toilet_flush',
    'pig',
    'washing_machine',
    'clock_tick',
    'sneezing',
    'rooster',
    'sea_waves',
    'siren',
    'cat',
    'door_wood_creaks',
    'helicopter',
    'crackling_fire',
    'car_horn',
    'brushing_teeth',
    'vacuum_cleaner',
    'thunderstorm',
    'door_wood_knock',
    'can_opening',
    'crow',
    'clapping',
    'fireworks',
    'chainsaw',
    'airplane',
    'mouse_click',
    'pouring_water',
    'train',
    'sheep',
    'water_drops',
    'church_bells',
    'clock_alarm',
    'keyboard_typing',
    'wind',
    'footsteps',
    'frog',
    'cow',
    'crickets'
]

# Create the dictionary
reversed_labels = {i: label for i, label in enumerate(labels)}

NUM_CLASSES = len(reversed_labels)

# %%
# Load arrays from a file
with np.load('/kaggle/input/esc50-specs-checkpoint/checkpoint_esc50_specs.npz') as data:
    X_train_specs = data['X_train_specs']
    X_val_specs = data['X_val_specs']
    X_test_specs = data['X_test_specs']
    y_train = data['y_train']
    y_val = data['y_val']
    y_test = data['y_test']

# %% [markdown]
# ## Audio splitting
#
# Create the train test partitions of the wavs. This implementation is designed to split the audio files directly from the augmented set of spectrograms to save computational cost.
#
# The fram rate of the spectrograms is determined by the size of the time axis. 5 second audios are sampled at 498 frames with the TensorFlow acoustic extraction.

# %%
def split_spectrograms(X, y, sr=(1 / (5 / X_train_specs.shape[1])), frame_duration=2, hop_duration=0.5):
    
    # Calculate number of time bins in a frame and in a hop
    frame_length = int(sr * frame_duration)
    hop_length = int(sr * hop_duration)
    
    if frame_length > X_train_specs.shape[1]:
        raise ValueError('Frame length is greater than time dimension of spectrograms')
    if hop_length > X_train_specs.shape[1]:
        raise ValueError('Hop length is greater than time dimension of spectrograms')
    
    # Number of frames and hops in each spectrogram
    n_frames_per_spectrogram = (X.shape[1] - frame_length) // hop_length + 1

    # Initialize lists to store the split spectrograms and labels
    X_split = []
    y_split = []

    # Loop over the spectrograms
    for i in range(X.shape[0]):
        # Loop over frames within the spectrogram
        for j in range(n_frames_per_spectrogram):
            start = j * hop_length
            end = start + frame_length
            # Slice the spectrogram to get the current frame
            X_split.append(X[i, start:end])
            # Append the corresponding label
            y_split.append(y[i])

    # Convert lists to arrays
    X_split = np.array(X_split)
    X_split = np.squeeze(X_split, axis=-1) # X_train_specs was processed as a TF Tensor. We convert to 2D array.
    y_split = np.array(y_split)

    return X_split, y_split

# %%
len(X_train_specs)
# Out:
# 4480

# %%
X_train_specs, y_train = split_spectrograms(X_train_specs, y_train)

# %%
len(X_train_specs)
# Out:
# 31360

# %%
X_val_specs, y_val = split_spectrograms(X_val_specs, y_val)

# %%
X_test_specs, y_test = split_spectrograms(X_test_specs, y_test)

# %%
# View 8 random spectrograms
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(16,16))

# Generate 8 random indices
indices = np.random.choice(len(X_train_specs), size=8, replace=False)

for i, ax in enumerate(axs.ravel()):
    idx = indices[i]  # use the randomly generated index
    ax.set_title(reversed_labels[y_train[idx]])
    spectrogram = X_train_specs[idx].T  # Transpose the spectrogram
    img = ax.imshow(spectrogram, aspect='auto', origin='lower', cmap='viridis')
    fig.colorbar(img, ax=ax)

plt.tight_layout()
plt.show()

# %%
X_train_specs = tf.expand_dims(X_train_specs, -1)  # add a channel dimension
X_val_specs = tf.expand_dims(X_val_specs, -1)  # add a channel dimension
X_test_specs = tf.expand_dims(X_test_specs, -1)  # add a channel dimension

# %% [markdown]
# ## Basic CNN Architecture

# %%
HLF = Sequential([
    tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
])

Embeddings = Sequential([
    tf.keras.layers.Conv2D(256, 1, padding='same', activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GlobalAveragePooling2D(),
])

# Define the model
model = Sequential([
    HLF,
    Embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')  # The activation should be softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(np.array(X_train_specs), np.array(y_train), epochs=50, batch_size=32*4, validation_data=(np.array(X_val_specs), np.array(y_val)))
# Out:
# Epoch 1/50
# 2023-06-10 23:16:29.421620: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_5/sequential_4/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 245/245 [==============================] - 12s 31ms/step - loss: 2.8434 - accuracy: 0.2457 - val_loss: 3.1559 - val_accuracy: 0.1643
# Epoch 2/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.9805 - accuracy: 0.4531 - val_loss: 2.1678 - val_accuracy: 0.4077
# Epoch 3/50
# 245/245 [==============================] - 7s 28ms/step - loss: 1.5525 - accuracy: 0.5698 - val_loss: 1.8405 - val_accuracy: 0.5316
# Epoch 4/50
# 245/245 [==============================] - 7s 28ms/step - loss: 1.2482 - accuracy: 0.6516 - val_loss: 2.0456 - val_accuracy: 0.5281
# Epoch 5/50
# 245/245 [==============================] - 7s 28ms/step - loss: 1.0291 - accuracy: 0.7125 - val_loss: 1.8011 - val_accuracy: 0.5786
# Epoch 6/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.8678 - accuracy: 0.7584 - val_loss: 2.1031 - val_accuracy: 0.5699
# Epoch 7/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.7485 - accuracy: 0.7879 - val_loss: 2.1605 - val_accuracy: 0.5622
# Epoch 8/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.6481 - accuracy: 0.8201 - val_loss: 2.0961 - val_accuracy: 0.5786
# Epoch 9/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.5760 - accuracy: 0.8383 - val_loss: 2.3217 - val_accuracy: 0.5806
# Epoch 10/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.5109 - accuracy: 0.8560 - val_loss: 2.0884 - val_accuracy: 0.5816
# Epoch 11/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4676 - accuracy: 0.8665 - val_loss: 2.3849 - val_accuracy: 0.5750
# Epoch 12/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.4283 - accuracy: 0.8792 - val_loss: 2.4265 - val_accuracy: 0.5495
# Epoch 13/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.3912 - accuracy: 0.8868 - val_loss: 2.3312 - val_accuracy: 0.5587
# Epoch 14/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.3699 - accuracy: 0.8939 - val_loss: 2.4377 - val_accuracy: 0.5740
# Epoch 15/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.3407 - accuracy: 0.9026 - val_loss: 2.8374 - val_accuracy: 0.5653
# Epoch 16/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3163 - accuracy: 0.9092 - val_loss: 3.0207 - val_accuracy: 0.5633
# Epoch 17/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2943 - accuracy: 0.9144 - val_loss: 2.7738 - val_accuracy: 0.5704
# Epoch 18/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2716 - accuracy: 0.9211 - val_loss: 2.5631 - val_accuracy: 0.5985
# Epoch 19/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2607 - accuracy: 0.9233 - val_loss: 3.0467 - val_accuracy: 0.5617
# Epoch 20/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2448 - accuracy: 0.9281 - val_loss: 2.2831 - val_accuracy: 0.5883
# Epoch 21/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2380 - accuracy: 0.9300 - val_loss: 3.0240 - val_accuracy: 0.5719
# Epoch 22/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2217 - accuracy: 0.9335 - val_loss: 2.7739 - val_accuracy: 0.5883
# Epoch 23/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2068 - accuracy: 0.9397 - val_loss: 3.4099 - val_accuracy: 0.5684
# Epoch 24/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2078 - accuracy: 0.9387 - val_loss: 3.0456 - val_accuracy: 0.5929
# Epoch 25/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1862 - accuracy: 0.9463 - val_loss: 3.1689 - val_accuracy: 0.5510
# Epoch 26/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1820 - accuracy: 0.9464 - val_loss: 3.3322 - val_accuracy: 0.5842
# Epoch 27/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1753 - accuracy: 0.9483 - val_loss: 3.7324 - val_accuracy: 0.5617
# Epoch 28/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1771 - accuracy: 0.9477 - val_loss: 3.2582 - val_accuracy: 0.5704
# Epoch 29/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.1568 - accuracy: 0.9532 - val_loss: 3.3120 - val_accuracy: 0.5577
# Epoch 30/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1513 - accuracy: 0.9557 - val_loss: 3.7731 - val_accuracy: 0.5628
# Epoch 31/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1568 - accuracy: 0.9536 - val_loss: 3.6068 - val_accuracy: 0.5668
# Epoch 32/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1611 - accuracy: 0.9514 - val_loss: 3.4285 - val_accuracy: 0.5944
# Epoch 33/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1515 - accuracy: 0.9540 - val_loss: 3.6928 - val_accuracy: 0.5571
# Epoch 34/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1304 - accuracy: 0.9629 - val_loss: 3.7819 - val_accuracy: 0.5699
# Epoch 35/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1293 - accuracy: 0.9616 - val_loss: 3.5183 - val_accuracy: 0.5862
# Epoch 36/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1449 - accuracy: 0.9577 - val_loss: 3.6753 - val_accuracy: 0.5694
# Epoch 37/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1289 - accuracy: 0.9622 - val_loss: 3.4970 - val_accuracy: 0.5760
# Epoch 38/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1115 - accuracy: 0.9679 - val_loss: 3.6848 - val_accuracy: 0.5954
# Epoch 39/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1213 - accuracy: 0.9636 - val_loss: 4.0018 - val_accuracy: 0.5791
# Epoch 40/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1379 - accuracy: 0.9575 - val_loss: 3.5419 - val_accuracy: 0.5806
# Epoch 41/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1116 - accuracy: 0.9672 - val_loss: 3.6541 - val_accuracy: 0.6097
# Epoch 42/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1074 - accuracy: 0.9688 - val_loss: 4.0003 - val_accuracy: 0.5770
# Epoch 43/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1231 - accuracy: 0.9628 - val_loss: 4.2073 - val_accuracy: 0.5546
# Epoch 44/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.1154 - accuracy: 0.9666 - val_loss: 3.6172 - val_accuracy: 0.6026
# Epoch 45/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1011 - accuracy: 0.9703 - val_loss: 3.7310 - val_accuracy: 0.5755
# Epoch 46/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1077 - accuracy: 0.9680 - val_loss: 4.6132 - val_accuracy: 0.5515
# Epoch 47/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.1033 - accuracy: 0.9693 - val_loss: 4.3525 - val_accuracy: 0.5745
# Epoch 48/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1161 - accuracy: 0.9659 - val_loss: 5.0804 - val_accuracy: 0.5316
# Epoch 49/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1110 - accuracy: 0.9657 - val_loss: 4.1021 - val_accuracy: 0.5791
# Epoch 50/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.1186 - accuracy: 0.9640 - val_loss: 3.8099 - val_accuracy: 0.5893

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_specs), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 132/132 - 1s - loss: 3.8758 - accuracy: 0.6100 - 536ms/epoch - 4ms/step
# Test loss: 3.875810384750366
# Test accuracy: 0.6100000143051147

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 139826

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 12, 4, 128)        93952
#
#  sequential_4 (Sequential)   (None, 256)               33024
#
#  dense_1 (Dense)             (None, 50)                12850
#
#  activation_1 (Activation)   (None, 50)                0
#
# =================================================================
# Total params: 139,826
# Trainable params: 139,186
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_esc50_al2s_basic.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(X_test_specs)
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 132/132 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Depth Wise Separable Convolutions

# %%
## Basic CNN Architecture

HLF = Sequential([
    tf.keras.layers.SeparableConv2D(32, 3, strides=2, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.SeparableConv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.SeparableConv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
])

Embeddings = Sequential([
    tf.keras.layers.Conv2D(256, 1, padding='same', activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GlobalAveragePooling2D(),
])

# Define the model
model = Sequential([
    HLF,
    Embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')  # The activation should be softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(np.array(X_train_specs), np.array(y_train), epochs=50, batch_size=32*4, validation_data=(np.array(X_val_specs), np.array(y_val)))
# Out:
# Epoch 1/50
# 2023-06-10 23:05:42.843323: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/sequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 245/245 [==============================] - 21s 33ms/step - loss: 3.1000 - accuracy: 0.1822 - val_loss: 3.8962 - val_accuracy: 0.0179
# Epoch 2/50
# 245/245 [==============================] - 7s 28ms/step - loss: 2.3623 - accuracy: 0.3503 - val_loss: 3.0260 - val_accuracy: 0.1617
# Epoch 3/50
# 245/245 [==============================] - 7s 29ms/step - loss: 2.0192 - accuracy: 0.4372 - val_loss: 5.7504 - val_accuracy: 0.1888
# Epoch 4/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.7727 - accuracy: 0.5066 - val_loss: 2.0738 - val_accuracy: 0.4730
# Epoch 5/50
# 245/245 [==============================] - 7s 28ms/step - loss: 1.5879 - accuracy: 0.5556 - val_loss: 1.9478 - val_accuracy: 0.4980
# Epoch 6/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.4352 - accuracy: 0.5926 - val_loss: 2.0432 - val_accuracy: 0.5158
# Epoch 7/50
# 245/245 [==============================] - 7s 28ms/step - loss: 1.3081 - accuracy: 0.6274 - val_loss: 2.0190 - val_accuracy: 0.5148
# Epoch 8/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.2045 - accuracy: 0.6562 - val_loss: 2.0996 - val_accuracy: 0.5357
# Epoch 9/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.1151 - accuracy: 0.6815 - val_loss: 1.9371 - val_accuracy: 0.5219
# Epoch 10/50
# 245/245 [==============================] - 7s 29ms/step - loss: 1.0253 - accuracy: 0.7063 - val_loss: 2.0651 - val_accuracy: 0.5194
# Epoch 11/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.9551 - accuracy: 0.7261 - val_loss: 2.3030 - val_accuracy: 0.5153
# Epoch 12/50
# 245/245 [==============================] - 7s 30ms/step - loss: 0.8881 - accuracy: 0.7456 - val_loss: 2.3299 - val_accuracy: 0.5199
# Epoch 13/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.8388 - accuracy: 0.7572 - val_loss: 2.3926 - val_accuracy: 0.5255
# Epoch 14/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.7969 - accuracy: 0.7684 - val_loss: 2.3528 - val_accuracy: 0.5449
# Epoch 15/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.7517 - accuracy: 0.7857 - val_loss: 2.4775 - val_accuracy: 0.5505
# Epoch 16/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.7094 - accuracy: 0.7948 - val_loss: 2.5379 - val_accuracy: 0.5265
# Epoch 17/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.6792 - accuracy: 0.8026 - val_loss: 2.4588 - val_accuracy: 0.5296
# Epoch 18/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.6401 - accuracy: 0.8176 - val_loss: 2.5545 - val_accuracy: 0.5240
# Epoch 19/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.6100 - accuracy: 0.8251 - val_loss: 2.5172 - val_accuracy: 0.5378
# Epoch 20/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.5854 - accuracy: 0.8323 - val_loss: 2.5519 - val_accuracy: 0.5444
# Epoch 21/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.5689 - accuracy: 0.8348 - val_loss: 2.5472 - val_accuracy: 0.5653
# Epoch 22/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.5453 - accuracy: 0.8421 - val_loss: 2.6968 - val_accuracy: 0.5464
# Epoch 23/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.5250 - accuracy: 0.8497 - val_loss: 2.7005 - val_accuracy: 0.5270
# Epoch 24/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.5118 - accuracy: 0.8503 - val_loss: 2.7810 - val_accuracy: 0.5398
# Epoch 25/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4861 - accuracy: 0.8582 - val_loss: 2.9412 - val_accuracy: 0.5209
# Epoch 26/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4767 - accuracy: 0.8607 - val_loss: 2.9087 - val_accuracy: 0.5337
# Epoch 27/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4632 - accuracy: 0.8644 - val_loss: 2.8219 - val_accuracy: 0.5510
# Epoch 28/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4591 - accuracy: 0.8679 - val_loss: 5.4050 - val_accuracy: 0.3842
# Epoch 29/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4359 - accuracy: 0.8719 - val_loss: 3.2821 - val_accuracy: 0.5087
# Epoch 30/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4225 - accuracy: 0.8775 - val_loss: 3.2350 - val_accuracy: 0.5321
# Epoch 31/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4176 - accuracy: 0.8773 - val_loss: 3.0456 - val_accuracy: 0.5337
# Epoch 32/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.4063 - accuracy: 0.8812 - val_loss: 3.2600 - val_accuracy: 0.5199
# Epoch 33/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3967 - accuracy: 0.8852 - val_loss: 3.3325 - val_accuracy: 0.5214
# Epoch 34/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3815 - accuracy: 0.8890 - val_loss: 3.1745 - val_accuracy: 0.5383
# Epoch 35/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3705 - accuracy: 0.8908 - val_loss: 3.3600 - val_accuracy: 0.5194
# Epoch 36/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3691 - accuracy: 0.8920 - val_loss: 3.5360 - val_accuracy: 0.5265
# Epoch 37/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3525 - accuracy: 0.8965 - val_loss: 3.2389 - val_accuracy: 0.5520
# Epoch 38/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3561 - accuracy: 0.8950 - val_loss: 3.3093 - val_accuracy: 0.5332
# Epoch 39/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3480 - accuracy: 0.8978 - val_loss: 3.5488 - val_accuracy: 0.5490
# Epoch 40/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3363 - accuracy: 0.9007 - val_loss: 3.6386 - val_accuracy: 0.5306
# Epoch 41/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3320 - accuracy: 0.9030 - val_loss: 3.8263 - val_accuracy: 0.5311
# Epoch 42/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3222 - accuracy: 0.9038 - val_loss: 3.5957 - val_accuracy: 0.5510
# Epoch 43/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3244 - accuracy: 0.9050 - val_loss: 3.7501 - val_accuracy: 0.5235
# Epoch 44/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3198 - accuracy: 0.9060 - val_loss: 3.5482 - val_accuracy: 0.5204
# Epoch 45/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.3104 - accuracy: 0.9074 - val_loss: 3.9280 - val_accuracy: 0.5199
# Epoch 46/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2967 - accuracy: 0.9128 - val_loss: 3.8061 - val_accuracy: 0.5250
# Epoch 47/50
# 245/245 [==============================] - 7s 28ms/step - loss: 0.2939 - accuracy: 0.9132 - val_loss: 3.7279 - val_accuracy: 0.5255
# Epoch 48/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.2946 - accuracy: 0.9123 - val_loss: 3.5874 - val_accuracy: 0.5520
# Epoch 49/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.2870 - accuracy: 0.9148 - val_loss: 3.9391 - val_accuracy: 0.5235
# Epoch 50/50
# 245/245 [==============================] - 7s 29ms/step - loss: 0.2888 - accuracy: 0.9143 - val_loss: 3.9603 - val_accuracy: 0.5398

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_specs), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 132/132 - 1s - loss: 3.5224 - accuracy: 0.5695 - 709ms/epoch - 5ms/step
# Test loss: 3.52237868309021
# Test accuracy: 0.569523811340332

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 58523

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 12, 4, 128)        12649
#
#  sequential_1 (Sequential)   (None, 256)               33024
#
#  dense (Dense)               (None, 50)                12850
#
#  activation (Activation)     (None, 50)                0
#
# =================================================================
# Total params: 58,523
# Trainable params: 57,883
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_esc50_al2s_DW.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(X_test_specs)
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 132/132 [==============================] - 1s 3ms/step
