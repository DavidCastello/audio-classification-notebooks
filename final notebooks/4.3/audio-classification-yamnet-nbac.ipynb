# %% [markdown]
# # Transfer Learning with YAMNET
# ## Audio Classification with the NBAC dataset
#
# This notebook performs audio classification on audio fragments of 5 seconds long

# %%
# IMPORT ALL LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import random
import seaborn as sns

import librosa
import librosa.display

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.layers import Layer, Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay

import tensorflow_hub as hub
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ## Load the data
#
# ### ESC-50 dataset

# %%
# Set sample rate to work with at 8000

SR = 16000

# %%
# !git clone https://github.com/DavidCastello/NBAC.git
# Out:
# Cloning into 'NBAC'...
# remote: Enumerating objects: 734, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 734 (delta 2), reused 86 (delta 2), pack-reused 647
# Receiving objects: 100% (734/734), 443.54 MiB | 26.04 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# Updating files: 100% (723/723), done.

# %%
def map_subfolders_to_int(path):
    reversed_labels = {}
    counter = 0

    # Walk through the directory
    for root, dirs, files in os.walk(path):
        # For each subdirectory
        for dir in dirs:
            # Add the subdirectory to the dictionary with the current count as the key
            reversed_labels[counter] = dir
            counter += 1

    return reversed_labels

# Specify your directory path here
directory_path = "/kaggle/working/NBAC/audio"
reversed_labels = map_subfolders_to_int(directory_path)
print(reversed_labels)
# Out:
# {0: 'talking', 1: 'loud breathing', 2: 'rain', 3: 'coughing', 4: 'sneezing', 5: 'traffic', 6: 'dog bark', 7: 'wind', 8: 'snoring', 9: 'bed movement', 10: 'silence', 11: 'siren'}

# %%
NUM_CLASSES = len(reversed_labels)

# %%
def reverse_dict(original_dict):
    reversed_dict = {value: key for key, value in original_dict.items()}
    return reversed_dict

# reversed dictionary
labels_dict = reverse_dict(reversed_labels)
print(labels_dict)
# Out:
# {'talking': 0, 'loud breathing': 1, 'rain': 2, 'coughing': 3, 'sneezing': 4, 'traffic': 5, 'dog bark': 6, 'wind': 7, 'snoring': 8, 'bed movement': 9, 'silence': 10, 'siren': 11}

# %% [markdown]
# ### Load the wav files

# %%
NBAC_FOLDER = '/kaggle/working/NBAC/audio'

# %%
def wav_data_loader(directory, sr=SR, normalization=True):
    all_fragments = []
    for root, dirs, _ in os.walk(directory):
        for dir in dirs:
            dir_path = os.path.join(root, dir)
            files = [f for f in os.listdir(dir_path) if f.endswith('.wav')]
            for file in files:
                file_path = os.path.join(dir_path, file)
                # Load the audio file
                sample, sample_rate = librosa.load(file_path, sr=sr)
                if normalization:
                    # Normalize the waveform
                    sample = librosa.util.normalize(sample)
                # Append the sample and its label (subfolder name) as a tuple
                all_fragments.append((sample, labels_dict[dir]))
    return all_fragments

# %%
# %%time
nbac_wav_dataset = wav_data_loader(NBAC_FOLDER, normalization=False)
len(nbac_wav_dataset)
# Out:
# CPU times: user 13.8 s, sys: 684 ms, total: 14.5 s
# Wall time: 16.2 s
# 720

# %% [markdown]
# ## Train-test split
#
# Creating a first train-test split in the original dataset will be useful for correct data augmentation and pre-processing techniques.

# %%
X = [wav[0] for wav in nbac_wav_dataset]
y = [wav[1] for wav in nbac_wav_dataset]

X_train_wav, X_test_wav, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
X_train_wav, X_val_wav, y_train, y_val = train_test_split(X_train_wav, y_train, test_size=0.2, stratify=y_train, random_state=42)

# %% [markdown]
# ## Waveform augmentation

# %%
def add_noise(wav_data, noise_factor):

    # Generate noise signal with the same shape as input waveform
    noise = np.random.normal(0, 1, len(wav_data))

    # Scale noise signal with the permissible noise factor value
    noise *= noise_factor

    # Add noise signal to input waveform
    augmented_wav_data = wav_data + noise

    # Normalize the augmented waveform data
    augmented_wav_data = librosa.util.normalize(augmented_wav_data)

    return augmented_wav_data

def time_shift(audio, p):
    """
    Shift audio to the left or right by a random amount.
    """
    # Calculate the length of the audio array
    length = audio.shape[0]

    # Calculate the maximum number of samples to shift
    max_shift = int(length * p)

    # Generate a random shift value
    shift = random.randint(-max_shift, max_shift)

    # Create an empty array with the same shape as the audio array
    shifted_audio = np.zeros_like(audio)

    # Shift the audio by the specified number of samples
    if shift > 0:
      # Shift to the right
        shifted_audio[shift:] = audio[:length-shift]
    else:
        # Shift to the left
        shifted_audio[:length+shift] = audio[-shift:]
    
    if np.sum(shifted_audio) == 0:
        #revert the process if all information was erased
        shifted_audio = audio     

    return shifted_audio

def time_stretching(audio,factor):
    
    wav_time_stch = librosa.effects.time_stretch(audio,rate=factor)
    
    return wav_time_stch[:SR*5]

# %%
# %%time
''' EXUCUTE THIS CELL TO APPLY DATA AUGMENTATION
Lots of memory required this step could be optimized'''

def augment_wavs(wav_dataset, y):
    
    wav_dataset_augmented = []

    for wav in wav_dataset:
        # Create a copy of the original wav to prevent unwanted side effects
        temp_wav = wav.copy()
        temp_wav = add_noise(temp_wav, 0.025) # We want to use values between 0.005 and 0.04
        temp_wav = time_shift(temp_wav, 0.3)  # We want to use a max shift of 30%
        temp_wav = time_stretching(temp_wav, 0.85)

        wav_dataset_augmented.append(temp_wav)

    # Add original wavs to augmented list
    wav_dataset_augmented.extend(wav_dataset)
    
    y = y + y #each spec is being appended at the bottom of the list

    return wav_dataset_augmented, y

X_train_wav, y_train = augment_wavs(X_train_wav, y_train)
# Out:
# CPU times: user 24.2 s, sys: 227 ms, total: 24.5 s
# Wall time: 24.8 s

# %% [markdown]
# # Training

# %%
# Extract the embeddings with Yamnet

yamnet_model_handle = 'https://tfhub.dev/google/yamnet/1'
yamnet_model = hub.load(yamnet_model_handle)

# %%
# %%time

def extract_embeddings(waveforms):
    embeddings_list = []
    for waveform in waveforms:
        _, embeddings, _ = yamnet_model(waveform)
        embeddings_list.append(np.array(embeddings))
    return embeddings_list

X_train_embeddings = extract_embeddings(X_train_wav)

X_val_embeddings = extract_embeddings(X_val_wav)

X_test_embeddings = extract_embeddings(X_test_wav)
# Out:
# CPU times: user 6.72 s, sys: 1.22 s, total: 7.94 s
# Wall time: 12.1 s

# %%
X_train_embeddings[0].shape
# Out:
# (10, 1024)

# %%
len(X_train_embeddings)
# Out:
# 806

# %%
# # TO USE SEPARATED EMBEDDINGS

def split_embeddings_and_labels(X_embeddings, y):
    X_split = []
    y_split = []
    idx = []
    
    for i in range(len(X_embeddings)):
        for j in range(len(X_embeddings[i])):
            X_split.append(X_embeddings[i][j])
            y_split.append(y[i])
            idx.append(i)
    
    return X_split, y_split, idx
    
X_train_embeddings, y_train, index =  split_embeddings_and_labels(X_train_embeddings, y_train)
X_val_embeddings, y_val, index =  split_embeddings_and_labels(X_val_embeddings, y_val)
X_test_embeddings, y_test, index =  split_embeddings_and_labels(X_test_embeddings, y_test)

# %%
'''
# TO USE ALL THE EMBEDDINGS FLATTENED

def reshape_data(X_embeddings):
    X_reshaped = []
    for embedding in X_embeddings:
        embedding = embedding.flatten()
        X_reshaped.append(embedding)
    return X_reshaped
    
X_train_embeddings =  reshape_data(X_train_embeddings)
X_val_embeddings =  reshape_data(X_val_embeddings)
X_test_embeddings =  reshape_data(X_test_embeddings)
'''
# Out:
# '\n# TO USE ALL THE EMBEDDINGS FLATTENED\n\ndef reshape_data(X_embeddings):\n    X_reshaped = []\n    for embedding in X_embeddings:\n        embedding = embedding.flatten()\n        X_reshaped.append(embedding)\n    return X_reshaped\n    \nX_train_embeddings =  reshape_data(X_train_embeddings)\nX_val_embeddings =  reshape_data(X_val_embeddings)\nX_test_embeddings =  reshape_data(X_test_embeddings)\n'

# %%
X_train_embeddings[0].shape
# Out:
# (1024,)

# %%
# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train_embeddings[0].shape), dtype=tf.float32, name='input_embedding'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
earlystopping = EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='auto')

# Define model checkpoint
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

callbacks = [earlystopping, model_checkpoint]

history = model.fit(np.array(X_train_embeddings), np.array(y_train), epochs=50, batch_size=32, validation_data=(np.array(X_val_embeddings), np.array(y_val)), callbacks=callbacks)
# Out:
# Epoch 1/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.9479 - accuracy: 0.4102
# Epoch 1: val_loss improved from inf to 1.20009, saving model to best_model.h5
# 252/252 [==============================] - 3s 4ms/step - loss: 1.9406 - accuracy: 0.4117 - val_loss: 1.2001 - val_accuracy: 0.6723
# Epoch 2/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.5402 - accuracy: 0.5282
# Epoch 2: val_loss improved from 1.20009 to 1.07514, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.5373 - accuracy: 0.5288 - val_loss: 1.0751 - val_accuracy: 0.6762
# Epoch 3/50
# 251/252 [============================>.] - ETA: 0s - loss: 1.4249 - accuracy: 0.5553
# Epoch 3: val_loss improved from 1.07514 to 1.05931, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.4263 - accuracy: 0.5548 - val_loss: 1.0593 - val_accuracy: 0.6594
# Epoch 4/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.3731 - accuracy: 0.5643
# Epoch 4: val_loss improved from 1.05931 to 1.01829, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.3760 - accuracy: 0.5630 - val_loss: 1.0183 - val_accuracy: 0.6624
# Epoch 5/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.3396 - accuracy: 0.5699
# Epoch 5: val_loss improved from 1.01829 to 0.96620, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.3396 - accuracy: 0.5702 - val_loss: 0.9662 - val_accuracy: 0.6851
# Epoch 6/50
# 248/252 [============================>.] - ETA: 0s - loss: 1.2987 - accuracy: 0.5777
# Epoch 6: val_loss improved from 0.96620 to 0.92570, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.3002 - accuracy: 0.5772 - val_loss: 0.9257 - val_accuracy: 0.6871
# Epoch 7/50
# 242/252 [===========================>..] - ETA: 0s - loss: 1.2683 - accuracy: 0.5839
# Epoch 7: val_loss improved from 0.92570 to 0.84525, saving model to best_model.h5
# 252/252 [==============================] - 1s 4ms/step - loss: 1.2672 - accuracy: 0.5840 - val_loss: 0.8452 - val_accuracy: 0.7238
# Epoch 8/50
# 241/252 [===========================>..] - ETA: 0s - loss: 1.2483 - accuracy: 0.5943
# Epoch 8: val_loss did not improve from 0.84525
# 252/252 [==============================] - 1s 3ms/step - loss: 1.2517 - accuracy: 0.5942 - val_loss: 0.8830 - val_accuracy: 0.6901
# Epoch 9/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.2337 - accuracy: 0.5967
# Epoch 9: val_loss did not improve from 0.84525
# 252/252 [==============================] - 1s 3ms/step - loss: 1.2322 - accuracy: 0.5974 - val_loss: 0.8540 - val_accuracy: 0.7129
# Epoch 10/50
# 242/252 [===========================>..] - ETA: 0s - loss: 1.2314 - accuracy: 0.6010
# Epoch 10: val_loss improved from 0.84525 to 0.82550, saving model to best_model.h5
# 252/252 [==============================] - 1s 4ms/step - loss: 1.2272 - accuracy: 0.6019 - val_loss: 0.8255 - val_accuracy: 0.7297
# Epoch 11/50
# 252/252 [==============================] - ETA: 0s - loss: 1.2150 - accuracy: 0.6042
# Epoch 11: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.2150 - accuracy: 0.6042 - val_loss: 0.8953 - val_accuracy: 0.7020
# Epoch 12/50
# 234/252 [==========================>...] - ETA: 0s - loss: 1.2026 - accuracy: 0.6076
# Epoch 12: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1983 - accuracy: 0.6083 - val_loss: 0.8630 - val_accuracy: 0.7356
# Epoch 13/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.2064 - accuracy: 0.6084
# Epoch 13: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.2082 - accuracy: 0.6078 - val_loss: 0.8773 - val_accuracy: 0.7158
# Epoch 14/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.1753 - accuracy: 0.6123
# Epoch 14: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1760 - accuracy: 0.6115 - val_loss: 0.9018 - val_accuracy: 0.7059
# Epoch 15/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.1628 - accuracy: 0.6159
# Epoch 15: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1599 - accuracy: 0.6164 - val_loss: 0.8718 - val_accuracy: 0.7188
# Epoch 16/50
# 233/252 [==========================>...] - ETA: 0s - loss: 1.1709 - accuracy: 0.6183
# Epoch 16: val_loss did not improve from 0.82550
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1683 - accuracy: 0.6205 - val_loss: 0.8651 - val_accuracy: 0.7307
# Epoch 17/50
# 251/252 [============================>.] - ETA: 0s - loss: 1.1532 - accuracy: 0.6209
# Epoch 17: val_loss improved from 0.82550 to 0.82109, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1533 - accuracy: 0.6210 - val_loss: 0.8211 - val_accuracy: 0.7356
# Epoch 18/50
# 249/252 [============================>.] - ETA: 0s - loss: 1.1529 - accuracy: 0.6219
# Epoch 18: val_loss did not improve from 0.82109
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1519 - accuracy: 0.6230 - val_loss: 0.8792 - val_accuracy: 0.7129
# Epoch 19/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.1381 - accuracy: 0.6273
# Epoch 19: val_loss improved from 0.82109 to 0.81987, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1362 - accuracy: 0.6277 - val_loss: 0.8199 - val_accuracy: 0.7327
# Epoch 20/50
# 249/252 [============================>.] - ETA: 0s - loss: 1.1253 - accuracy: 0.6264
# Epoch 20: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 4ms/step - loss: 1.1247 - accuracy: 0.6258 - val_loss: 0.9276 - val_accuracy: 0.7426
# Epoch 21/50
# 235/252 [==========================>...] - ETA: 0s - loss: 1.1289 - accuracy: 0.6297
# Epoch 21: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1307 - accuracy: 0.6293 - val_loss: 0.8369 - val_accuracy: 0.7455
# Epoch 22/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.1291 - accuracy: 0.6305
# Epoch 22: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1278 - accuracy: 0.6310 - val_loss: 0.9832 - val_accuracy: 0.7089
# Epoch 23/50
# 243/252 [===========================>..] - ETA: 0s - loss: 1.1054 - accuracy: 0.6364
# Epoch 23: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1053 - accuracy: 0.6365 - val_loss: 0.8245 - val_accuracy: 0.7366
# Epoch 24/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.1119 - accuracy: 0.6319
# Epoch 24: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1108 - accuracy: 0.6316 - val_loss: 0.8351 - val_accuracy: 0.7248
# Epoch 25/50
# 238/252 [===========================>..] - ETA: 0s - loss: 1.1066 - accuracy: 0.6359
# Epoch 25: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1084 - accuracy: 0.6359 - val_loss: 0.8455 - val_accuracy: 0.7149
# Epoch 26/50
# 240/252 [===========================>..] - ETA: 0s - loss: 1.1009 - accuracy: 0.6349
# Epoch 26: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1029 - accuracy: 0.6352 - val_loss: 0.8487 - val_accuracy: 0.7396
# Epoch 27/50
# 241/252 [===========================>..] - ETA: 0s - loss: 1.1107 - accuracy: 0.6395
# Epoch 27: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1100 - accuracy: 0.6395 - val_loss: 0.8285 - val_accuracy: 0.7208
# Epoch 28/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.1087 - accuracy: 0.6388
# Epoch 28: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.1063 - accuracy: 0.6395 - val_loss: 0.9335 - val_accuracy: 0.7020
# Epoch 29/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.0948 - accuracy: 0.6408
# Epoch 29: val_loss did not improve from 0.81987
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0940 - accuracy: 0.6414 - val_loss: 0.9083 - val_accuracy: 0.7406
# Epoch 30/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.0862 - accuracy: 0.6421
# Epoch 30: val_loss improved from 0.81987 to 0.81816, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0861 - accuracy: 0.6422 - val_loss: 0.8182 - val_accuracy: 0.7317
# Epoch 31/50
# 250/252 [============================>.] - ETA: 0s - loss: 1.0762 - accuracy: 0.6440
# Epoch 31: val_loss improved from 0.81816 to 0.81355, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0778 - accuracy: 0.6433 - val_loss: 0.8136 - val_accuracy: 0.7416
# Epoch 32/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.0717 - accuracy: 0.6477
# Epoch 32: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 4ms/step - loss: 1.0753 - accuracy: 0.6457 - val_loss: 0.8234 - val_accuracy: 0.7436
# Epoch 33/50
# 246/252 [============================>.] - ETA: 0s - loss: 1.0940 - accuracy: 0.6425
# Epoch 33: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0990 - accuracy: 0.6422 - val_loss: 0.8214 - val_accuracy: 0.7386
# Epoch 34/50
# 241/252 [===========================>..] - ETA: 0s - loss: 1.0795 - accuracy: 0.6419
# Epoch 34: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0773 - accuracy: 0.6437 - val_loss: 1.0741 - val_accuracy: 0.7109
# Epoch 35/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.0731 - accuracy: 0.6453
# Epoch 35: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0728 - accuracy: 0.6458 - val_loss: 0.8442 - val_accuracy: 0.7416
# Epoch 36/50
# 246/252 [============================>.] - ETA: 0s - loss: 1.0603 - accuracy: 0.6472
# Epoch 36: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 4ms/step - loss: 1.0611 - accuracy: 0.6464 - val_loss: 0.9131 - val_accuracy: 0.7158
# Epoch 37/50
# 249/252 [============================>.] - ETA: 0s - loss: 1.0688 - accuracy: 0.6493
# Epoch 37: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 5ms/step - loss: 1.0701 - accuracy: 0.6486 - val_loss: 0.8870 - val_accuracy: 0.7436
# Epoch 38/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.0634 - accuracy: 0.6523
# Epoch 38: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0669 - accuracy: 0.6506 - val_loss: 0.8450 - val_accuracy: 0.7109
# Epoch 39/50
# 245/252 [============================>.] - ETA: 0s - loss: 1.0548 - accuracy: 0.6495
# Epoch 39: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0554 - accuracy: 0.6494 - val_loss: 0.9124 - val_accuracy: 0.7059
# Epoch 40/50
# 241/252 [===========================>..] - ETA: 0s - loss: 1.0758 - accuracy: 0.6512
# Epoch 40: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0766 - accuracy: 0.6516 - val_loss: 0.8748 - val_accuracy: 0.7366
# Epoch 41/50
# 244/252 [============================>.] - ETA: 0s - loss: 1.0532 - accuracy: 0.6556
# Epoch 41: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0523 - accuracy: 0.6551 - val_loss: 0.8214 - val_accuracy: 0.7426
# Epoch 42/50
# 243/252 [===========================>..] - ETA: 0s - loss: 1.0489 - accuracy: 0.6526
# Epoch 42: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0459 - accuracy: 0.6537 - val_loss: 0.8982 - val_accuracy: 0.7386
# Epoch 43/50
# 243/252 [===========================>..] - ETA: 0s - loss: 1.0764 - accuracy: 0.6532
# Epoch 43: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0757 - accuracy: 0.6526 - val_loss: 0.9349 - val_accuracy: 0.7406
# Epoch 44/50
# 234/252 [==========================>...] - ETA: 0s - loss: 1.0490 - accuracy: 0.6522
# Epoch 44: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0492 - accuracy: 0.6520 - val_loss: 0.9340 - val_accuracy: 0.7396
# Epoch 45/50
# 243/252 [===========================>..] - ETA: 0s - loss: 1.0448 - accuracy: 0.6560
# Epoch 45: val_loss did not improve from 0.81355
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0471 - accuracy: 0.6556 - val_loss: 0.8510 - val_accuracy: 0.7139
# Epoch 46/50
# 246/252 [============================>.] - ETA: 0s - loss: 1.0531 - accuracy: 0.6512
# Epoch 46: val_loss improved from 0.81355 to 0.80849, saving model to best_model.h5
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0505 - accuracy: 0.6515 - val_loss: 0.8085 - val_accuracy: 0.7455
# Epoch 47/50
# 240/252 [===========================>..] - ETA: 0s - loss: 1.0378 - accuracy: 0.6559
# Epoch 47: val_loss did not improve from 0.80849
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0387 - accuracy: 0.6566 - val_loss: 0.8669 - val_accuracy: 0.7416
# Epoch 48/50
# 246/252 [============================>.] - ETA: 0s - loss: 1.0326 - accuracy: 0.6555
# Epoch 48: val_loss did not improve from 0.80849
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0317 - accuracy: 0.6555 - val_loss: 0.8150 - val_accuracy: 0.7416
# Epoch 49/50
# 241/252 [===========================>..] - ETA: 0s - loss: 1.0348 - accuracy: 0.6599
# Epoch 49: val_loss did not improve from 0.80849
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0326 - accuracy: 0.6608 - val_loss: 0.8104 - val_accuracy: 0.7386
# Epoch 50/50
# 243/252 [===========================>..] - ETA: 0s - loss: 1.0363 - accuracy: 0.6582
# Epoch 50: val_loss did not improve from 0.80849
# 252/252 [==============================] - 1s 3ms/step - loss: 1.0354 - accuracy: 0.6586 - val_loss: 0.8363 - val_accuracy: 0.7416

# %%
model = load_model('/kaggle/working/best_model.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                12300
#
# =================================================================
# Total params: 12,300
# Trainable params: 12,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_embeddings), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 68/68 - 0s - loss: 0.6712 - accuracy: 0.7690 - 235ms/epoch - 3ms/step
# Test loss: 0.6711767911911011
# Test accuracy: 0.7689814567565918

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 12300

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_nbac_YamNet_al5s.h5')

# %% [markdown]
# ### Confussion matrix

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_embeddings))
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %% [markdown]
# # Real evaluation

# %% [markdown]
# ### Route 1: most common prediction

# %%
import pandas as pd

df = pd.DataFrame({
    'idx': index,
    'y_test': y_test,
    'y_pred': y_pred
})

df.head(20)
# Out:
#     idx  y_test  y_pred
# 0     0       9       9
# 1     0       9       1
# 2     0       9       1
# 3     0       9       9
# 4     0       9       9
# 5     0       9       9
# 6     0       9       9
# 7     0       9       1
# 8     0       9       9
# 9     0       9       9
# 10    1       0       4
# 11    1       0       0
# 12    1       0       2
# 13    1       0       4
# 14    1       0       1
# 15    1       0       0
# 16    1       0       0
# 17    1       0       0
# 18    1       0       0
# 19    1       0       0

# %%
# Assuming df is your DataFrame

# Group by 'idx' column and take first value of 'y_test' and the mode (most common) value of 'y_pred'
df_grouped = df.groupby('idx').agg({
    'y_test': 'first',
    'y_pred': lambda x: x.mode()[0] if len(x.mode()) > 0 else None
}).reset_index()

df_grouped.head(20)
# Out:
#     idx  y_test  y_pred
# 0     0       9       9
# 1     1       0       0
# 2     2      10      10
# 3     3       0       0
# 4     4       9       9
# 5     5       4       4
# 6     6       2       2
# 7     7       2       2
# 8     8       8       8
# 9     9       0       0
# 10   10       9       9
# 11   11       6       6
# 12   12      10      10
# 13   13       6       6
# 14   14       7       7
# 15   15       6       6
# 16   16       5       5
# 17   17       6       6
# 18   18      11       0
# 19   19       9       9

# %%
# Convert 'y_test' column to a numpy array
y_test = df_grouped['y_test'].values

# Convert 'y_pred' column to a numpy array
y_pred = df_grouped['y_pred'].values

# Calculate accuracy
accuracy = np.mean(y_test == y_pred)

print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 91.67%

# %% [markdown]
# ### Route 2: strongest prediction

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_embeddings))
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
y_pred[9]
# Out:
# array([6.3032135e-02, 2.4370392e-01, 6.4890948e-03, 7.7326521e-02,
#        2.0385933e-01, 2.6006179e-04, 4.4220682e-02, 1.5391957e-02,
#        5.8345515e-03, 3.1366274e-01, 1.4108522e-02, 1.2110505e-02],
#       dtype=float32)

# %%
# Create an empty list to hold the stacked arrays
y_pred_scores = []

# Iterate through array_list in steps of 10
for i in range(0, len(y_pred), 10):
    
    # Select 10 arrays and stack them together
    stacked = np.stack(y_pred[i:i+10])
    
    mean_array = np.mean(stacked, axis=0)
    
    # Append the stacked array to stacked_arrays
    y_pred_scores.append(mean_array)

# %%
len(y_test)
# Out:
# 216

# %%
len(y_pred_scores)
# Out:
# 216

# %%
y_pred = np.argmax(y_pred_scores, axis=1)

# %%
# Calculate accuracy
accuracy = np.mean(y_test == y_pred)

print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 94.91%
