# %% [markdown]
# # Compact architectures
# ## Audio Classification with the NBAC dataset
#
# This notebook performs audio classification on audio fragments of 2 seconds long

# %%
# IMPORT ALL LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import random
import seaborn as sns

import librosa
import librosa.display

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.layers import Layer, Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ## Load the data
#
# ### ESC-50 dataset

# %%
# Set sample rate to work with at 8000

SR = 16000

# %%
# !git clone https://github.com/DavidCastello/NBAC.git
# Out:
# Cloning into 'NBAC'...
# remote: Enumerating objects: 734, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 734 (delta 2), reused 86 (delta 2), pack-reused 647
# Receiving objects: 100% (734/734), 443.54 MiB | 27.38 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# Updating files: 100% (723/723), done.

# %%
def map_subfolders_to_int(path):
    reversed_labels = {}
    counter = 0

    # Walk through the directory
    for root, dirs, files in os.walk(path):
        # For each subdirectory
        for dir in dirs:
            # Add the subdirectory to the dictionary with the current count as the key
            reversed_labels[counter] = dir
            counter += 1

    return reversed_labels

# Specify your directory path here
directory_path = "/kaggle/working/NBAC/audio"
reversed_labels = map_subfolders_to_int(directory_path)
print(reversed_labels)
# Out:
# {0: 'rain', 1: 'silence', 2: 'siren', 3: 'coughing', 4: 'bed movement', 5: 'snoring', 6: 'traffic', 7: 'loud breathing', 8: 'sneezing', 9: 'talking', 10: 'dog bark', 11: 'wind'}

# %%
NUM_CLASSES = len(reversed_labels)

# %%
def reverse_dict(original_dict):
    reversed_dict = {value: key for key, value in original_dict.items()}
    return reversed_dict

# reversed dictionary
labels_dict = reverse_dict(reversed_labels)
print(labels_dict)
# Out:
# {'rain': 0, 'silence': 1, 'siren': 2, 'coughing': 3, 'bed movement': 4, 'snoring': 5, 'traffic': 6, 'loud breathing': 7, 'sneezing': 8, 'talking': 9, 'dog bark': 10, 'wind': 11}

# %% [markdown]
# ### Load the wav files

# %%
NBAC_FOLDER = '/kaggle/working/NBAC/audio'

# %%
def wav_data_loader(directory, sr=SR, normalization=True):
    all_fragments = []
    for root, dirs, _ in os.walk(directory):
        for dir in dirs:
            dir_path = os.path.join(root, dir)
            files = [f for f in os.listdir(dir_path) if f.endswith('.wav')]
            for file in files:
                file_path = os.path.join(dir_path, file)
                # Load the audio file
                sample, sample_rate = librosa.load(file_path, sr=sr)
                if normalization:
                    # Normalize the waveform
                    sample = librosa.util.normalize(sample)
                # Append the sample and its label (subfolder name) as a tuple
                all_fragments.append((sample, labels_dict[dir]))
    return all_fragments

# %%
# %%time
nbac_wav_dataset = wav_data_loader(NBAC_FOLDER, normalization=False)
len(nbac_wav_dataset)
# Out:
# CPU times: user 13.6 s, sys: 730 ms, total: 14.3 s
# Wall time: 16.9 s
# 720

# %% [markdown]
# ## Train-test split
#
# Creating a first train-test split in the original dataset will be useful for correct data augmentation and pre-processing techniques.

# %%
X = [wav[0] for wav in nbac_wav_dataset]
y = [wav[1] for wav in nbac_wav_dataset]

X_train_wav, X_test_wav, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
X_train_wav, X_val_wav, y_train, y_val = train_test_split(X_train_wav, y_train, test_size=0.2, stratify=y_train, random_state=42)

# %% [markdown]
# ## Waveform augmentation

# %%
## Noise addition

def add_noise(wav_data, noise_factor):

    # Generate noise signal with the same shape as input waveform
    noise = np.random.normal(0, 1, len(wav_data))

    # Scale noise signal with the permissible noise factor value
    noise *= noise_factor

    # Add noise signal to input waveform
    augmented_wav_data = wav_data + noise

    # Normalize the augmented waveform data
    augmented_wav_data = librosa.util.normalize(augmented_wav_data)

    return augmented_wav_data

def time_shift(audio, p):
    """
    Shift audio to the left or right by a random amount.
    """
    # Calculate the length of the audio array
    length = audio.shape[0]

    # Calculate the maximum number of samples to shift
    max_shift = int(length * p)

    # Generate a random shift value
    shift = random.randint(-max_shift, max_shift)

    # Create an empty array with the same shape as the audio array
    shifted_audio = np.zeros_like(audio)

    # Shift the audio by the specified number of samples
    if shift > 0:
      # Shift to the right
        shifted_audio[shift:] = audio[:length-shift]
    else:
        # Shift to the left
        shifted_audio[:length+shift] = audio[-shift:]
    
    if np.sum(shifted_audio) == 0:
        #revert the process if all information was erased
        shifted_audio = audio     

    return shifted_audio

def time_stretching(audio,factor):
    
    wav_time_stch = librosa.effects.time_stretch(audio,rate=factor)
    
    return wav_time_stch[:SR*5]

# %%
# %%time
''' EXUCUTE THIS CELL TO APPLY DATA AUGMENTATION
Lots of memory required this step could be optimized'''

def augment_wavs(wav_dataset, y):
    
    wav_dataset_augmented = []

    for wav in wav_dataset:
        # Create a copy of the original wav to prevent unwanted side effects
        temp_wav = wav.copy()
        temp_wav = add_noise(temp_wav, 0.025) # We want to use values between 0.005 and 0.04
        temp_wav = time_shift(temp_wav, 0.3)  # We want to use a max shift of 30%
        temp_wav = time_stretching(temp_wav, 0.85)

        wav_dataset_augmented.append(temp_wav)

    # Add original wavs to augmented list
    wav_dataset_augmented.extend(wav_dataset)
    
    y = y + y #each spec is being appended at the bottom of the list

    return wav_dataset_augmented, y

X_train_wav, y_train = augment_wavs(X_train_wav, y_train)
# Out:
# CPU times: user 24.2 s, sys: 230 ms, total: 24.4 s
# Wall time: 24.9 s

# %% [markdown]
# ## Split the waveforms

# %%
def split_waveforms(X_wav, y, sample_rate=SR, window_size=2, hop_size=0.5):
    
    # Define window size and hop size in samples
    window_size = window_size * sample_rate 
    hop_size = hop_size * sample_rate

    X_segments = []
    y_segments = []

    for i, waveform in enumerate(X_wav):
        for start in np.arange(0, waveform.size - window_size + 1, hop_size):
            end = start + window_size
            segment = waveform[int(start):int(end)]
            X_segments.append(segment)
            y_segments.append(y[i])  # Use the same label for the segment

    return X_segments, y_segments

# %%
X_train_wav, y_train = split_waveforms(X_train_wav, y_train)

# %%
X_val_wav, y_val = split_waveforms(X_val_wav, y_val)

# %%
X_test_wav, y_test = split_waveforms(X_test_wav, y_test)

# %% [markdown]
# # Training

# %% [markdown]
# ## Basic CNN architecture

# %%
class LLF(Layer):
    def __init__(self, sample_rate, frame_length, frame_step, num_mel_bins=64, lower_freq=125, upper_freq=7500, log_offset=0.001, **kwargs):
        super(LLF, self).__init__(**kwargs)
        self.sample_rate = sample_rate
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.num_mel_bins = num_mel_bins
        self.lower_freq = lower_freq
        self.upper_freq = upper_freq
        self.log_offset = log_offset

    def call(self, inputs):
        
        # Convert numpy array to Tensor and normalize based on its actual max and min values
        wav = tf.cast(inputs, tf.float32)
        audio_tensor = (wav - tf.math.reduce_min(wav)) / (tf.math.reduce_max(wav) - tf.math.reduce_min(wav)) * 2 - 1
        
        # Compute the Short-Time Fourier Transform (STFT)
        stft = tf.signal.stft(wav, self.frame_length, self.frame_step, window_fn=tf.signal.hann_window)

        # Compute the spectrogram
        spectrogram = tf.abs(stft)

        # Compute the mel-spectrogram
        num_spectrogram_bins = stft.shape[-1]
        linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
            self.num_mel_bins, num_spectrogram_bins, self.sample_rate, self.lower_freq, self.upper_freq)
        mel_spectrogram = tf.tensordot(spectrogram, linear_to_mel_weight_matrix, 1)
        mel_spectrogram.set_shape(spectrogram.shape[:-1].concatenate(linear_to_mel_weight_matrix.shape[-1:]))

        # Compute the log mel-spectrogram
        log_mel_spectrogram = tf.math.log(mel_spectrogram + self.log_offset)

        # Add a channel dimension
        log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, -1)

        return log_mel_spectrogram

sample_rate = SR  # Adjust as necessary
window_size_ms = 25
window_hop_ms = 10
frame_length = sample_rate * window_size_ms // 1000
frame_step = sample_rate * window_hop_ms // 1000
AUDIO_LENGTH = 2

class HLFBlock(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(HLFBlock, self).__init__(**kwargs)
        self.seq = Sequential([
            tf.keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        ])

    def call(self, inputs):
        return self.seq(inputs)

class EmbeddingsBlock(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(EmbeddingsBlock, self).__init__(**kwargs)
        self.seq = Sequential([
            tf.keras.layers.Conv2D(256, 1, padding='same', activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.GlobalAveragePooling2D(),
        ])

    def call(self, inputs):
        return self.seq(inputs)
    
HLF = HLFBlock(name='HLF')
Embeddings = EmbeddingsBlock(name='Embeddings')

# Define the model
model = Sequential([
    LLF(sample_rate, frame_length, frame_step, input_shape=(AUDIO_LENGTH*SR,)),
    HLF,
    Embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')  # The activation should be softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(np.array(X_train_wav), np.array(y_train), epochs=50, batch_size=32, validation_data=(np.array(X_val_wav), np.array(y_val)))
# Out:
# Epoch 1/50
# 2023-06-17 16:48:27.250877: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/Embeddings/sequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 177/177 [==============================] - 20s 18ms/step - loss: 1.8816 - accuracy: 0.3561 - val_loss: 2.3260 - val_accuracy: 0.2263
# Epoch 2/50
# 177/177 [==============================] - 2s 11ms/step - loss: 1.3841 - accuracy: 0.5186 - val_loss: 1.3969 - val_accuracy: 0.5233
# Epoch 3/50
# 177/177 [==============================] - 2s 12ms/step - loss: 1.0968 - accuracy: 0.6303 - val_loss: 0.9320 - val_accuracy: 0.6690
# Epoch 4/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.9061 - accuracy: 0.6935 - val_loss: 0.7247 - val_accuracy: 0.8006
# Epoch 5/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.7702 - accuracy: 0.7426 - val_loss: 0.9673 - val_accuracy: 0.7270
# Epoch 6/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.6803 - accuracy: 0.7644 - val_loss: 1.7665 - val_accuracy: 0.5035
# Epoch 7/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.6129 - accuracy: 0.7900 - val_loss: 0.8603 - val_accuracy: 0.7298
# Epoch 8/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5228 - accuracy: 0.8279 - val_loss: 1.8731 - val_accuracy: 0.5318
# Epoch 9/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.5088 - accuracy: 0.8240 - val_loss: 1.6432 - val_accuracy: 0.6238
# Epoch 10/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4296 - accuracy: 0.8571 - val_loss: 0.7378 - val_accuracy: 0.7397
# Epoch 11/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.3557 - accuracy: 0.8837 - val_loss: 0.7958 - val_accuracy: 0.7440
# Epoch 12/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.3059 - accuracy: 0.9006 - val_loss: 1.0888 - val_accuracy: 0.7440
# Epoch 13/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2713 - accuracy: 0.9096 - val_loss: 1.1849 - val_accuracy: 0.7171
# Epoch 14/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2204 - accuracy: 0.9305 - val_loss: 0.9091 - val_accuracy: 0.7553
# Epoch 15/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1808 - accuracy: 0.9475 - val_loss: 1.1989 - val_accuracy: 0.7199
# Epoch 16/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1701 - accuracy: 0.9502 - val_loss: 1.1148 - val_accuracy: 0.7355
# Epoch 17/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1301 - accuracy: 0.9617 - val_loss: 1.1900 - val_accuracy: 0.7680
# Epoch 18/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1183 - accuracy: 0.9642 - val_loss: 0.8821 - val_accuracy: 0.7779
# Epoch 19/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1552 - accuracy: 0.9484 - val_loss: 1.1123 - val_accuracy: 0.7581
# Epoch 20/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0950 - accuracy: 0.9706 - val_loss: 1.0278 - val_accuracy: 0.7100
# Epoch 21/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0982 - accuracy: 0.9720 - val_loss: 0.9067 - val_accuracy: 0.7822
# Epoch 22/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0921 - accuracy: 0.9709 - val_loss: 0.9862 - val_accuracy: 0.7864
# Epoch 23/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.1138 - accuracy: 0.9647 - val_loss: 0.8026 - val_accuracy: 0.8175
# Epoch 24/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0740 - accuracy: 0.9807 - val_loss: 0.9944 - val_accuracy: 0.8190
# Epoch 25/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0957 - accuracy: 0.9716 - val_loss: 2.4097 - val_accuracy: 0.6223
# Epoch 26/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1994 - accuracy: 0.9360 - val_loss: 2.3564 - val_accuracy: 0.6973
# Epoch 27/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.0892 - accuracy: 0.9709 - val_loss: 0.9504 - val_accuracy: 0.8175
# Epoch 28/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0556 - accuracy: 0.9839 - val_loss: 0.9679 - val_accuracy: 0.8076
# Epoch 29/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0563 - accuracy: 0.9828 - val_loss: 1.6194 - val_accuracy: 0.7723
# Epoch 30/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0782 - accuracy: 0.9761 - val_loss: 1.1272 - val_accuracy: 0.7482
# Epoch 31/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0582 - accuracy: 0.9825 - val_loss: 1.1223 - val_accuracy: 0.7864
# Epoch 32/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0815 - accuracy: 0.9741 - val_loss: 1.6369 - val_accuracy: 0.7383
# Epoch 33/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1006 - accuracy: 0.9674 - val_loss: 1.1687 - val_accuracy: 0.7850
# Epoch 34/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0714 - accuracy: 0.9771 - val_loss: 1.1283 - val_accuracy: 0.8048
# Epoch 35/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0438 - accuracy: 0.9883 - val_loss: 0.8658 - val_accuracy: 0.8331
# Epoch 36/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0521 - accuracy: 0.9830 - val_loss: 1.3349 - val_accuracy: 0.7553
# Epoch 37/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0532 - accuracy: 0.9832 - val_loss: 1.3845 - val_accuracy: 0.7737
# Epoch 38/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0965 - accuracy: 0.9700 - val_loss: 2.0807 - val_accuracy: 0.7072
# Epoch 39/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1070 - accuracy: 0.9651 - val_loss: 1.7277 - val_accuracy: 0.7058
# Epoch 40/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0589 - accuracy: 0.9819 - val_loss: 1.3453 - val_accuracy: 0.7808
# Epoch 41/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0506 - accuracy: 0.9848 - val_loss: 1.1901 - val_accuracy: 0.7779
# Epoch 42/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.0328 - accuracy: 0.9911 - val_loss: 1.0654 - val_accuracy: 0.8232
# Epoch 43/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0654 - accuracy: 0.9782 - val_loss: 1.8102 - val_accuracy: 0.7666
# Epoch 44/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1058 - accuracy: 0.9656 - val_loss: 1.3348 - val_accuracy: 0.7284
# Epoch 45/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0705 - accuracy: 0.9757 - val_loss: 1.0951 - val_accuracy: 0.8006
# Epoch 46/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0752 - accuracy: 0.9759 - val_loss: 1.2436 - val_accuracy: 0.7709
# Epoch 47/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0388 - accuracy: 0.9887 - val_loss: 1.2250 - val_accuracy: 0.8048
# Epoch 48/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.0474 - accuracy: 0.9840 - val_loss: 1.5201 - val_accuracy: 0.7638
# Epoch 49/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0409 - accuracy: 0.9865 - val_loss: 1.0602 - val_accuracy: 0.8062
# Epoch 50/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0470 - accuracy: 0.9862 - val_loss: 1.4898 - val_accuracy: 0.7284

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_wav), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 48/48 - 0s - loss: 1.3569 - accuracy: 0.7632 - 325ms/epoch - 7ms/step
# Test loss: 1.3569039106369019
# Test accuracy: 0.7632275223731995

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 129676

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  llf (LLF)                   (None, 198, 64, 1)        0
#
#  HLF (HLFBlock)              (None, 12, 4, 128)        93568
#
#  Embeddings (EmbeddingsBlock  (None, 256)              33024
#  )
#
#  dense (Dense)               (None, 12)                3084
#
#  activation (Activation)     (None, 12)                0
#
# =================================================================
# Total params: 129,676
# Trainable params: 129,228
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_nbac_basic_al2s.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_wav))
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 48/48 [==============================] - 1s 5ms/step

# %% [markdown]
# ### Visualize the ouput of the LLF

# %%
idx = 55
sample = X_test_wav[idx]
sample = sample.reshape(1, AUDIO_LENGTH * SR) # Add a batch dimension

# %%
# Get the output of the SpectrogramLayer
spectrogram_model = Model(inputs=model.inputs, outputs=model.get_layer(index=0).output)
spectrogram_output = spectrogram_model.predict(sample)

# Create a figure with custom size (e.g., width=10 inches, height=6 inches)
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title(reversed_labels[y_test[idx]])
spectrogram = spectrogram_output.squeeze().T  # Transpose the spectrogram and remove redundant dimensions

img = ax.imshow(spectrogram, aspect='auto', origin='lower', cmap='viridis')
fig.colorbar(img, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 356ms/step

# %% [markdown]
# ## Depthwise Spearable Convolutions

# %%
class LLF(Layer):
    def __init__(self, sample_rate, frame_length, frame_step, num_mel_bins=64, lower_freq=125, upper_freq=7500, log_offset=0.001, **kwargs):
        super(LLF, self).__init__(**kwargs)
        self.sample_rate = sample_rate
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.num_mel_bins = num_mel_bins
        self.lower_freq = lower_freq
        self.upper_freq = upper_freq
        self.log_offset = log_offset

    def call(self, inputs):
        
        # Convert numpy array to Tensor and normalize based on its actual max and min values
        wav = tf.cast(inputs, tf.float32)
        audio_tensor = (wav - tf.math.reduce_min(wav)) / (tf.math.reduce_max(wav) - tf.math.reduce_min(wav)) * 2 - 1
        
        # Compute the Short-Time Fourier Transform (STFT)
        stft = tf.signal.stft(wav, self.frame_length, self.frame_step, window_fn=tf.signal.hann_window)

        # Compute the spectrogram
        spectrogram = tf.abs(stft)

        # Compute the mel-spectrogram
        num_spectrogram_bins = stft.shape[-1]
        linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
            self.num_mel_bins, num_spectrogram_bins, self.sample_rate, self.lower_freq, self.upper_freq)
        mel_spectrogram = tf.tensordot(spectrogram, linear_to_mel_weight_matrix, 1)
        mel_spectrogram.set_shape(spectrogram.shape[:-1].concatenate(linear_to_mel_weight_matrix.shape[-1:]))

        # Compute the log mel-spectrogram
        log_mel_spectrogram = tf.math.log(mel_spectrogram + self.log_offset)

        # Add a channel dimension
        log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, -1)

        return log_mel_spectrogram

sample_rate = SR  # Adjust as necessary
window_size_ms = 25
window_hop_ms = 10
frame_length = sample_rate * window_size_ms // 1000
frame_step = sample_rate * window_hop_ms // 1000
AUDIO_LENGTH = 2

class HLFBlock(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(HLFBlock, self).__init__(**kwargs)
        self.seq = Sequential([
            tf.keras.layers.SeparableConv2D(32, 3, strides=2, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.SeparableConv2D(64, 3, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.SeparableConv2D(128, 3, padding='same', activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        ])

    def call(self, inputs):
        return self.seq(inputs)

class EmbeddingsBlock(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(EmbeddingsBlock, self).__init__(**kwargs)
        self.seq = Sequential([
            tf.keras.layers.Conv2D(256, 1, padding='same', activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.GlobalAveragePooling2D(),
        ])

    def call(self, inputs):
        return self.seq(inputs)
    
HLF = HLFBlock(name='HLF')
Embeddings = EmbeddingsBlock(name='Embeddings')

# Define the model
model = Sequential([
    LLF(sample_rate, frame_length, frame_step, input_shape=(AUDIO_LENGTH*SR,)),
    HLF,
    Embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')  # The activation should be softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(np.array(X_train_wav), np.array(y_train), epochs=50, batch_size=32, validation_data=(np.array(X_val_wav), np.array(y_val)))
# Out:
# Epoch 1/50
# 2023-06-17 16:50:37.067213: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_5/Embeddings/sequential_4/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 177/177 [==============================] - 8s 19ms/step - loss: 1.9440 - accuracy: 0.3337 - val_loss: 2.4952 - val_accuracy: 0.0891
# Epoch 2/50
# 177/177 [==============================] - 2s 11ms/step - loss: 1.4560 - accuracy: 0.5044 - val_loss: 2.2870 - val_accuracy: 0.2291
# Epoch 3/50
# 177/177 [==============================] - 2s 12ms/step - loss: 1.2364 - accuracy: 0.5766 - val_loss: 1.1943 - val_accuracy: 0.6690
# Epoch 4/50
# 177/177 [==============================] - 2s 11ms/step - loss: 1.0843 - accuracy: 0.6306 - val_loss: 0.8175 - val_accuracy: 0.7595
# Epoch 5/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.9601 - accuracy: 0.6765 - val_loss: 0.8142 - val_accuracy: 0.7242
# Epoch 6/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.8723 - accuracy: 0.7077 - val_loss: 0.7488 - val_accuracy: 0.7751
# Epoch 7/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.8011 - accuracy: 0.7318 - val_loss: 0.8059 - val_accuracy: 0.7454
# Epoch 8/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.7539 - accuracy: 0.7467 - val_loss: 0.9338 - val_accuracy: 0.7779
# Epoch 9/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.7043 - accuracy: 0.7566 - val_loss: 0.8341 - val_accuracy: 0.7284
# Epoch 10/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.6719 - accuracy: 0.7730 - val_loss: 0.8971 - val_accuracy: 0.7652
# Epoch 11/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.6415 - accuracy: 0.7777 - val_loss: 0.9289 - val_accuracy: 0.7694
# Epoch 12/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.6026 - accuracy: 0.7948 - val_loss: 1.0789 - val_accuracy: 0.7581
# Epoch 13/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5824 - accuracy: 0.8063 - val_loss: 0.9820 - val_accuracy: 0.7822
# Epoch 14/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.5610 - accuracy: 0.8098 - val_loss: 1.0539 - val_accuracy: 0.7369
# Epoch 15/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.5163 - accuracy: 0.8213 - val_loss: 0.9621 - val_accuracy: 0.7567
# Epoch 16/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.5060 - accuracy: 0.8251 - val_loss: 1.1727 - val_accuracy: 0.7369
# Epoch 17/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4805 - accuracy: 0.8384 - val_loss: 0.8933 - val_accuracy: 0.7935
# Epoch 18/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4876 - accuracy: 0.8311 - val_loss: 0.9155 - val_accuracy: 0.8034
# Epoch 19/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.4359 - accuracy: 0.8524 - val_loss: 1.0867 - val_accuracy: 0.7581
# Epoch 20/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.4186 - accuracy: 0.8559 - val_loss: 0.8841 - val_accuracy: 0.8006
# Epoch 21/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.3826 - accuracy: 0.8719 - val_loss: 0.9860 - val_accuracy: 0.7921
# Epoch 22/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.3748 - accuracy: 0.8722 - val_loss: 0.9568 - val_accuracy: 0.7751
# Epoch 23/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.3712 - accuracy: 0.8708 - val_loss: 1.0101 - val_accuracy: 0.7638
# Epoch 24/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.3413 - accuracy: 0.8906 - val_loss: 1.0306 - val_accuracy: 0.7426
# Epoch 25/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.3406 - accuracy: 0.8871 - val_loss: 1.1915 - val_accuracy: 0.7779
# Epoch 26/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2956 - accuracy: 0.9055 - val_loss: 1.0378 - val_accuracy: 0.7765
# Epoch 27/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.2891 - accuracy: 0.9048 - val_loss: 1.0719 - val_accuracy: 0.7793
# Epoch 28/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.2885 - accuracy: 0.9006 - val_loss: 1.2259 - val_accuracy: 0.7723
# Epoch 29/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2732 - accuracy: 0.9103 - val_loss: 1.4091 - val_accuracy: 0.7397
# Epoch 30/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.2534 - accuracy: 0.9093 - val_loss: 1.2653 - val_accuracy: 0.7454
# Epoch 31/50
# 177/177 [==============================] - 2s 13ms/step - loss: 0.2315 - accuracy: 0.9252 - val_loss: 1.2687 - val_accuracy: 0.7680
# Epoch 32/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2228 - accuracy: 0.9293 - val_loss: 1.2461 - val_accuracy: 0.7765
# Epoch 33/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2113 - accuracy: 0.9342 - val_loss: 1.1332 - val_accuracy: 0.7893
# Epoch 34/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.2294 - accuracy: 0.9233 - val_loss: 1.2688 - val_accuracy: 0.7426
# Epoch 35/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1900 - accuracy: 0.9399 - val_loss: 1.3917 - val_accuracy: 0.7751
# Epoch 36/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1821 - accuracy: 0.9419 - val_loss: 1.2840 - val_accuracy: 0.7793
# Epoch 37/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1990 - accuracy: 0.9323 - val_loss: 1.2107 - val_accuracy: 0.7907
# Epoch 38/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1566 - accuracy: 0.9500 - val_loss: 1.2642 - val_accuracy: 0.7511
# Epoch 39/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1748 - accuracy: 0.9465 - val_loss: 1.1290 - val_accuracy: 0.7793
# Epoch 40/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1546 - accuracy: 0.9518 - val_loss: 1.3263 - val_accuracy: 0.7567
# Epoch 41/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1407 - accuracy: 0.9589 - val_loss: 1.3142 - val_accuracy: 0.7709
# Epoch 42/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1479 - accuracy: 0.9514 - val_loss: 1.2736 - val_accuracy: 0.7567
# Epoch 43/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1416 - accuracy: 0.9568 - val_loss: 1.2570 - val_accuracy: 0.7751
# Epoch 44/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1360 - accuracy: 0.9568 - val_loss: 1.5360 - val_accuracy: 0.7638
# Epoch 45/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1295 - accuracy: 0.9585 - val_loss: 1.4023 - val_accuracy: 0.7723
# Epoch 46/50
# 177/177 [==============================] - 2s 14ms/step - loss: 0.1277 - accuracy: 0.9596 - val_loss: 1.5132 - val_accuracy: 0.7652
# Epoch 47/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1347 - accuracy: 0.9585 - val_loss: 1.2815 - val_accuracy: 0.7779
# Epoch 48/50
# 177/177 [==============================] - 2s 12ms/step - loss: 0.1318 - accuracy: 0.9594 - val_loss: 1.4405 - val_accuracy: 0.7723
# Epoch 49/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.1108 - accuracy: 0.9683 - val_loss: 1.5098 - val_accuracy: 0.7779
# Epoch 50/50
# 177/177 [==============================] - 2s 11ms/step - loss: 0.0931 - accuracy: 0.9709 - val_loss: 1.3502 - val_accuracy: 0.7822

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_wav), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 48/48 - 0s - loss: 1.0052 - accuracy: 0.7943 - 324ms/epoch - 7ms/step
# Test loss: 1.0051746368408203
# Test accuracy: 0.7943121790885925

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 48373

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  llf_1 (LLF)                 (None, 198, 64, 1)        0
#
#  HLF (HLFBlock)              (None, 12, 4, 128)        12265
#
#  Embeddings (EmbeddingsBlock  (None, 256)              33024
#  )
#
#  dense_1 (Dense)             (None, 12)                3084
#
#  activation_1 (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 48,373
# Trainable params: 47,925
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_nbac_dw_al2s.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_wav))
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 48/48 [==============================] - 1s 5ms/step

# %% [markdown]
# ### Visualize the ouput of the LLF

# %%
idx = 55
sample = X_test_wav[idx]
sample = sample.reshape(1, AUDIO_LENGTH * SR) # Add a batch dimension

# %%
# Get the output of the SpectrogramLayer
spectrogram_model = Model(inputs=model.inputs, outputs=model.get_layer(index=0).output)
spectrogram_output = spectrogram_model.predict(sample)

# Create a figure with custom size (e.g., width=10 inches, height=6 inches)
fig, ax = plt.subplots(figsize=(8, 4))
ax.set_title(reversed_labels[y_test[idx]])
spectrogram = spectrogram_output.squeeze().T  # Transpose the spectrogram and remove redundant dimensions

img = ax.imshow(spectrogram, aspect='auto', origin='lower', cmap='viridis')
fig.colorbar(img, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 298ms/step

# %% [markdown]
# ## Transfer Learning with Mobilenet_v1
#
# ## Mobilenet_v1 with randomly initialized weights

# %%
# Load the MobileNetV1 model but exclude the top layers
mobilenet_model = MobileNet(weights=None, include_top=False, input_shape=(198, 64, 3))

class LLF_3channels(Layer):
    def __init__(self, sample_rate, frame_length, frame_step, num_mel_bins=64, lower_freq=125, upper_freq=7500, log_offset=0.001, **kwargs):
        super(LLF_3channels, self).__init__(**kwargs)
        self.sample_rate = sample_rate
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.num_mel_bins = num_mel_bins
        self.lower_freq = lower_freq
        self.upper_freq = upper_freq
        self.log_offset = log_offset

    def call(self, inputs):
        
        # Convert numpy array to Tensor and normalize based on its actual max and min values
        wav = tf.cast(inputs, tf.float32)
        audio_tensor = (wav - tf.math.reduce_min(wav)) / (tf.math.reduce_max(wav) - tf.math.reduce_min(wav)) * 2 - 1
        
        # Compute the Short-Time Fourier Transform (STFT)
        stft = tf.signal.stft(wav, self.frame_length, self.frame_step, window_fn=tf.signal.hann_window)

        # Compute the spectrogram
        spectrogram = tf.abs(stft)

        # Compute the mel-spectrogram
        num_spectrogram_bins = stft.shape[-1]
        linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
            self.num_mel_bins, num_spectrogram_bins, self.sample_rate, self.lower_freq, self.upper_freq)
        mel_spectrogram = tf.tensordot(spectrogram, linear_to_mel_weight_matrix, 1)
        mel_spectrogram.set_shape(spectrogram.shape[:-1].concatenate(linear_to_mel_weight_matrix.shape[-1:]))

        # Compute the log mel-spectrogram
        log_mel_spectrogram = tf.math.log(mel_spectrogram + self.log_offset)

        # Add a channel dimension
        log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, -1)
        
        # Convert 1-channel image to 3-channel image
        x = tf.repeat(log_mel_spectrogram, 3, axis=-1)
        
        return x

sample_rate = 16000  # Adjust as necessary
window_size_ms = 25
window_hop_ms = 10
frame_length = sample_rate * window_size_ms // 1000
frame_step = sample_rate * window_hop_ms // 1000
audio_length = sample_rate*2

class MobileNetEmbeddings(Model):
    def __init__(self, base_model, **kwargs):
        super(MobileNetEmbeddings, self).__init__(**kwargs)
        self.base_model = base_model
        self.pooling = GlobalAveragePooling2D()
        
    def call(self, inputs):
        x = self.base_model(inputs)
        return self.pooling(x)

MobileNet_embeddings = MobileNetEmbeddings(mobilenet_model, name="MobileNet_embeddings")

# Define the model
model = Sequential([
    LLF_3channels(sample_rate=sample_rate, frame_length=frame_length, frame_step=frame_step, input_shape=(audio_length,)),
    MobileNet_embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')
])

for layer in mobilenet_model.layers:
    layer.trainable = True

# Define a learning rate
learning_rate = 0.001/2 # With low learning rates the model gets stuck at local minumums that cause overfitting.
                        # With high learning rates the performance is inconsistent

# Initialize the Adam optimizer with the lower learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
earlystopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto')

# Define model checkpoint
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

callbacks = [earlystopping, model_checkpoint]

# Train the model
history = model.fit(np.array(X_train_wav), np.array(y_train), epochs=50, batch_size=32, 
                    validation_data=(np.array(X_val_wav), np.array(y_val)),
                    callbacks=callbacks)
# Out:
# Epoch 1/50
# 177/177 [==============================] - ETA: 0s - loss: 2.1286 - accuracy: 0.2581
# Epoch 1: val_loss improved from inf to 2.57236, saving model to best_model.h5
# 177/177 [==============================] - 26s 49ms/step - loss: 2.1286 - accuracy: 0.2581 - val_loss: 2.5724 - val_accuracy: 0.0792
# Epoch 2/50
# 177/177 [==============================] - ETA: 0s - loss: 1.6409 - accuracy: 0.4250
# Epoch 2: val_loss did not improve from 2.57236
# 177/177 [==============================] - 6s 37ms/step - loss: 1.6409 - accuracy: 0.4250 - val_loss: 2.6676 - val_accuracy: 0.0792
# Epoch 3/50
# 177/177 [==============================] - ETA: 0s - loss: 1.4216 - accuracy: 0.4903
# Epoch 3: val_loss did not improve from 2.57236
# 177/177 [==============================] - 7s 37ms/step - loss: 1.4216 - accuracy: 0.4903 - val_loss: 3.0336 - val_accuracy: 0.0891
# Epoch 4/50
# 177/177 [==============================] - ETA: 0s - loss: 1.2432 - accuracy: 0.5590
# Epoch 4: val_loss improved from 2.57236 to 1.70899, saving model to best_model.h5
# 177/177 [==============================] - 7s 39ms/step - loss: 1.2432 - accuracy: 0.5590 - val_loss: 1.7090 - val_accuracy: 0.4272
# Epoch 5/50
# 177/177 [==============================] - ETA: 0s - loss: 1.0939 - accuracy: 0.6117
# Epoch 5: val_loss improved from 1.70899 to 1.44072, saving model to best_model.h5
# 177/177 [==============================] - 7s 39ms/step - loss: 1.0939 - accuracy: 0.6117 - val_loss: 1.4407 - val_accuracy: 0.6379
# Epoch 6/50
# 177/177 [==============================] - ETA: 0s - loss: 0.9903 - accuracy: 0.6533
# Epoch 6: val_loss improved from 1.44072 to 1.28835, saving model to best_model.h5
# 177/177 [==============================] - 7s 39ms/step - loss: 0.9903 - accuracy: 0.6533 - val_loss: 1.2883 - val_accuracy: 0.6775
# Epoch 7/50
# 177/177 [==============================] - ETA: 0s - loss: 0.8776 - accuracy: 0.6852
# Epoch 7: val_loss improved from 1.28835 to 1.13736, saving model to best_model.h5
# 177/177 [==============================] - 7s 38ms/step - loss: 0.8776 - accuracy: 0.6852 - val_loss: 1.1374 - val_accuracy: 0.6945
# Epoch 8/50
# 177/177 [==============================] - ETA: 0s - loss: 0.7726 - accuracy: 0.7294
# Epoch 8: val_loss did not improve from 1.13736
# 177/177 [==============================] - 6s 37ms/step - loss: 0.7726 - accuracy: 0.7294 - val_loss: 1.6698 - val_accuracy: 0.6252
# Epoch 9/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.7027 - accuracy: 0.7532
# Epoch 9: val_loss did not improve from 1.13736
# 177/177 [==============================] - 7s 37ms/step - loss: 0.7028 - accuracy: 0.7533 - val_loss: 1.7412 - val_accuracy: 0.6124
# Epoch 10/50
# 177/177 [==============================] - ETA: 0s - loss: 0.6110 - accuracy: 0.7818
# Epoch 10: val_loss did not improve from 1.13736
# 177/177 [==============================] - 6s 36ms/step - loss: 0.6110 - accuracy: 0.7818 - val_loss: 1.4103 - val_accuracy: 0.7100
# Epoch 11/50
# 177/177 [==============================] - ETA: 0s - loss: 0.6296 - accuracy: 0.7831
# Epoch 11: val_loss did not improve from 1.13736
# 177/177 [==============================] - 6s 36ms/step - loss: 0.6296 - accuracy: 0.7831 - val_loss: 1.3135 - val_accuracy: 0.6761
# Epoch 12/50
# 177/177 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.8178
# Epoch 12: val_loss improved from 1.13736 to 1.13717, saving model to best_model.h5
# 177/177 [==============================] - 7s 38ms/step - loss: 0.5272 - accuracy: 0.8178 - val_loss: 1.1372 - val_accuracy: 0.7256
# Epoch 13/50
# 177/177 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.8323
# Epoch 13: val_loss improved from 1.13717 to 1.05801, saving model to best_model.h5
# 177/177 [==============================] - 7s 38ms/step - loss: 0.4904 - accuracy: 0.8323 - val_loss: 1.0580 - val_accuracy: 0.7214
# Epoch 14/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.4743 - accuracy: 0.8400
# Epoch 14: val_loss improved from 1.05801 to 0.95387, saving model to best_model.h5
# 177/177 [==============================] - 7s 39ms/step - loss: 0.4747 - accuracy: 0.8400 - val_loss: 0.9539 - val_accuracy: 0.7765
# Epoch 15/50
# 177/177 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.8584
# Epoch 15: val_loss did not improve from 0.95387
# 177/177 [==============================] - 7s 37ms/step - loss: 0.4001 - accuracy: 0.8584 - val_loss: 1.0827 - val_accuracy: 0.7907
# Epoch 16/50
# 177/177 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8669
# Epoch 16: val_loss did not improve from 0.95387
# 177/177 [==============================] - 6s 37ms/step - loss: 0.3874 - accuracy: 0.8669 - val_loss: 1.2487 - val_accuracy: 0.7525
# Epoch 17/50
# 177/177 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8763
# Epoch 17: val_loss improved from 0.95387 to 0.87221, saving model to best_model.h5
# 177/177 [==============================] - 7s 38ms/step - loss: 0.3630 - accuracy: 0.8763 - val_loss: 0.8722 - val_accuracy: 0.7793
# Epoch 18/50
# 177/177 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8972
# Epoch 18: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.3174 - accuracy: 0.8972 - val_loss: 1.4162 - val_accuracy: 0.7397
# Epoch 19/50
# 177/177 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.8993
# Epoch 19: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.3057 - accuracy: 0.8993 - val_loss: 1.2627 - val_accuracy: 0.7567
# Epoch 20/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9153
# Epoch 20: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.2519 - accuracy: 0.9151 - val_loss: 1.1414 - val_accuracy: 0.7369
# Epoch 21/50
# 177/177 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9211
# Epoch 21: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.2348 - accuracy: 0.9211 - val_loss: 1.2867 - val_accuracy: 0.7426
# Epoch 22/50
# 177/177 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9295
# Epoch 22: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.2208 - accuracy: 0.9295 - val_loss: 1.1628 - val_accuracy: 0.7652
# Epoch 23/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.1966 - accuracy: 0.9359
# Epoch 23: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.1964 - accuracy: 0.9360 - val_loss: 1.1461 - val_accuracy: 0.7765
# Epoch 24/50
# 177/177 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9335
# Epoch 24: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.2021 - accuracy: 0.9335 - val_loss: 1.2752 - val_accuracy: 0.7850
# Epoch 25/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9381
# Epoch 25: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.1911 - accuracy: 0.9381 - val_loss: 1.1757 - val_accuracy: 0.7723
# Epoch 26/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.9364
# Epoch 26: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.1909 - accuracy: 0.9365 - val_loss: 1.5668 - val_accuracy: 0.7765
# Epoch 27/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9435
# Epoch 27: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 36ms/step - loss: 0.1754 - accuracy: 0.9435 - val_loss: 1.7707 - val_accuracy: 0.7397
# Epoch 28/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9443
# Epoch 28: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 36ms/step - loss: 0.1706 - accuracy: 0.9443 - val_loss: 2.0272 - val_accuracy: 0.6478
# Epoch 29/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9558
# Epoch 29: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 38ms/step - loss: 0.1301 - accuracy: 0.9555 - val_loss: 1.1038 - val_accuracy: 0.7907
# Epoch 30/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9587
# Epoch 30: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.1260 - accuracy: 0.9587 - val_loss: 1.6544 - val_accuracy: 0.7383
# Epoch 31/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9546
# Epoch 31: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 36ms/step - loss: 0.1385 - accuracy: 0.9546 - val_loss: 1.2278 - val_accuracy: 0.7836
# Epoch 32/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9644
# Epoch 32: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.1137 - accuracy: 0.9644 - val_loss: 1.0521 - val_accuracy: 0.7709
# Epoch 33/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9591
# Epoch 33: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.1281 - accuracy: 0.9591 - val_loss: 1.5739 - val_accuracy: 0.7581
# Epoch 34/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9603
# Epoch 34: val_loss did not improve from 0.87221
# 177/177 [==============================] - 7s 37ms/step - loss: 0.1254 - accuracy: 0.9603 - val_loss: 1.0118 - val_accuracy: 0.7878
# Epoch 35/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9618
# Epoch 35: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 36ms/step - loss: 0.1225 - accuracy: 0.9617 - val_loss: 0.8911 - val_accuracy: 0.7949
# Epoch 36/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9546
# Epoch 36: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 37ms/step - loss: 0.1456 - accuracy: 0.9546 - val_loss: 1.3629 - val_accuracy: 0.7921
# Epoch 37/50
# 177/177 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9704
# Epoch 37: val_loss did not improve from 0.87221
# 177/177 [==============================] - 6s 36ms/step - loss: 0.0878 - accuracy: 0.9704 - val_loss: 1.4062 - val_accuracy: 0.7723
# Epoch 37: early stopping

# %%
model.load_weights('best_model.h5')

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_wav), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 48/48 - 1s - loss: 0.7913 - accuracy: 0.7963 - 742ms/epoch - 15ms/step
# Test loss: 0.791288435459137
# Test accuracy: 0.7962962985038757

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 3241164

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  llf_3channels (LLF_3channel  (None, 198, 64, 3)       0
#  s)
#
#  MobileNet_embeddings (Mobil  (None, 1024)             3228864
#  eNetEmbeddings)
#
#  dense_2 (Dense)             (None, 12)                12300
#
#  activation_2 (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 3,241,164
# Trainable params: 3,219,276
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_nbac_mobilenet_random_al2s.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_wav))
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 48/48 [==============================] - 1s 12ms/step

# %% [markdown]
# ## Transfer learning with Imagenet

# %%
# Load the MobileNetV1 model but exclude the top layers
mobilenet_model = MobileNet(weights='imagenet', include_top=False, input_shape=(198, 64, 3))

class LLF_3channels(Layer):
    def __init__(self, sample_rate, frame_length, frame_step, num_mel_bins=64, lower_freq=125, upper_freq=7500, log_offset=0.001, **kwargs):
        super(LLF_3channels, self).__init__(**kwargs)
        self.sample_rate = sample_rate
        self.frame_length = frame_length
        self.frame_step = frame_step
        self.num_mel_bins = num_mel_bins
        self.lower_freq = lower_freq
        self.upper_freq = upper_freq
        self.log_offset = log_offset

    def call(self, inputs):
        
        # Convert numpy array to Tensor and normalize based on its actual max and min values
        wav = tf.cast(inputs, tf.float32)
        audio_tensor = (wav - tf.math.reduce_min(wav)) / (tf.math.reduce_max(wav) - tf.math.reduce_min(wav)) * 2 - 1
        
        # Compute the Short-Time Fourier Transform (STFT)
        stft = tf.signal.stft(wav, self.frame_length, self.frame_step, window_fn=tf.signal.hann_window)

        # Compute the spectrogram
        spectrogram = tf.abs(stft)

        # Compute the mel-spectrogram
        num_spectrogram_bins = stft.shape[-1]
        linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
            self.num_mel_bins, num_spectrogram_bins, self.sample_rate, self.lower_freq, self.upper_freq)
        mel_spectrogram = tf.tensordot(spectrogram, linear_to_mel_weight_matrix, 1)
        mel_spectrogram.set_shape(spectrogram.shape[:-1].concatenate(linear_to_mel_weight_matrix.shape[-1:]))

        # Compute the log mel-spectrogram
        log_mel_spectrogram = tf.math.log(mel_spectrogram + self.log_offset)

        # Add a channel dimension
        log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, -1)
        
        # Convert 1-channel image to 3-channel image
        x = tf.repeat(log_mel_spectrogram, 3, axis=-1)
        
        return x

sample_rate = 16000  # Adjust as necessary
window_size_ms = 25
window_hop_ms = 10
frame_length = sample_rate * window_size_ms // 1000
frame_step = sample_rate * window_hop_ms // 1000
audio_length = sample_rate*2

class MobileNetEmbeddings(Model):
    def __init__(self, base_model, **kwargs):
        super(MobileNetEmbeddings, self).__init__(**kwargs)
        self.base_model = base_model
        self.pooling = GlobalAveragePooling2D()
        
    def call(self, inputs):
        x = self.base_model(inputs)
        return self.pooling(x)

MobileNet_embeddings = MobileNetEmbeddings(mobilenet_model, name="MobileNet_embeddings")

# Define the model
model = Sequential([
    LLF_3channels(sample_rate=sample_rate, frame_length=frame_length, frame_step=frame_step, input_shape=(audio_length,)),
    MobileNet_embeddings,
    tf.keras.layers.Dense(NUM_CLASSES),
    tf.keras.layers.Activation('softmax')
])

for layer in mobilenet_model.layers[:20]: #The first 20 layers of the model are frozen
    layer.trainable = False

# Define a learning rate
learning_rate = 0.001/2 # With low learning rates the model gets stuck at local minumums that cause overfitting.
                        # With high learning rates the performance is inconsistent

# Initialize the Adam optimizer with the lower learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
earlystopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='auto')

# Define model checkpoint
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

callbacks = [earlystopping, model_checkpoint]

# Train the model
history = model.fit(np.array(X_train_wav), np.array(y_train), epochs=50, batch_size=32, 
                    validation_data=(np.array(X_val_wav), np.array(y_val)),
                    callbacks=callbacks)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Epoch 1/50
# 175/177 [============================>.] - ETA: 0s - loss: 1.3280 - accuracy: 0.5746
# Epoch 1: val_loss improved from inf to 1.94300, saving model to best_model.h5
# 177/177 [==============================] - 19s 37ms/step - loss: 1.3242 - accuracy: 0.5757 - val_loss: 1.9430 - val_accuracy: 0.6153
# Epoch 2/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.7588
# Epoch 2: val_loss improved from 1.94300 to 1.10138, saving model to best_model.h5
# 177/177 [==============================] - 5s 30ms/step - loss: 0.7120 - accuracy: 0.7588 - val_loss: 1.1014 - val_accuracy: 0.7595
# Epoch 3/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.4472 - accuracy: 0.8484
# Epoch 3: val_loss improved from 1.10138 to 0.95316, saving model to best_model.h5
# 177/177 [==============================] - 6s 32ms/step - loss: 0.4475 - accuracy: 0.8483 - val_loss: 0.9532 - val_accuracy: 0.7624
# Epoch 4/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.2678 - accuracy: 0.9136
# Epoch 4: val_loss did not improve from 0.95316
# 177/177 [==============================] - 5s 29ms/step - loss: 0.2679 - accuracy: 0.9135 - val_loss: 1.4442 - val_accuracy: 0.7242
# Epoch 5/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.2106 - accuracy: 0.9289
# Epoch 5: val_loss improved from 0.95316 to 0.93996, saving model to best_model.h5
# 177/177 [==============================] - 5s 31ms/step - loss: 0.2102 - accuracy: 0.9293 - val_loss: 0.9400 - val_accuracy: 0.7723
# Epoch 6/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1466 - accuracy: 0.9523
# Epoch 6: val_loss did not improve from 0.93996
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1468 - accuracy: 0.9523 - val_loss: 1.7020 - val_accuracy: 0.6888
# Epoch 7/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9513
# Epoch 7: val_loss did not improve from 0.93996
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1576 - accuracy: 0.9509 - val_loss: 1.0207 - val_accuracy: 0.7864
# Epoch 8/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1101 - accuracy: 0.9627
# Epoch 8: val_loss did not improve from 0.93996
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1104 - accuracy: 0.9622 - val_loss: 1.0843 - val_accuracy: 0.7935
# Epoch 9/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1406 - accuracy: 0.9559
# Epoch 9: val_loss did not improve from 0.93996
# 177/177 [==============================] - 5s 30ms/step - loss: 0.1412 - accuracy: 0.9557 - val_loss: 1.2545 - val_accuracy: 0.7539
# Epoch 10/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1412 - accuracy: 0.9561
# Epoch 10: val_loss improved from 0.93996 to 0.90493, saving model to best_model.h5
# 177/177 [==============================] - 5s 30ms/step - loss: 0.1410 - accuracy: 0.9560 - val_loss: 0.9049 - val_accuracy: 0.7779
# Epoch 11/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9655
# Epoch 11: val_loss improved from 0.90493 to 0.70252, saving model to best_model.h5
# 177/177 [==============================] - 5s 30ms/step - loss: 0.1054 - accuracy: 0.9653 - val_loss: 0.7025 - val_accuracy: 0.8246
# Epoch 12/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1554 - accuracy: 0.9545
# Epoch 12: val_loss did not improve from 0.70252
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1557 - accuracy: 0.9543 - val_loss: 0.8350 - val_accuracy: 0.8006
# Epoch 13/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0576 - accuracy: 0.9795
# Epoch 13: val_loss did not improve from 0.70252
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0589 - accuracy: 0.9793 - val_loss: 0.8073 - val_accuracy: 0.8175
# Epoch 14/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9705
# Epoch 14: val_loss did not improve from 0.70252
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0934 - accuracy: 0.9706 - val_loss: 1.2048 - val_accuracy: 0.7765
# Epoch 15/50
# 177/177 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9676
# Epoch 15: val_loss did not improve from 0.70252
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1133 - accuracy: 0.9676 - val_loss: 1.1203 - val_accuracy: 0.7850
# Epoch 16/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1111 - accuracy: 0.9664
# Epoch 16: val_loss improved from 0.70252 to 0.68157, saving model to best_model.h5
# 177/177 [==============================] - 5s 31ms/step - loss: 0.1116 - accuracy: 0.9661 - val_loss: 0.6816 - val_accuracy: 0.8373
# Epoch 17/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9668
# Epoch 17: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.1157 - accuracy: 0.9669 - val_loss: 0.8455 - val_accuracy: 0.8062
# Epoch 18/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0687 - accuracy: 0.9786
# Epoch 18: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0687 - accuracy: 0.9784 - val_loss: 0.7413 - val_accuracy: 0.8373
# Epoch 19/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9818
# Epoch 19: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0530 - accuracy: 0.9817 - val_loss: 0.8482 - val_accuracy: 0.8020
# Epoch 20/50
# 176/177 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9725
# Epoch 20: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0824 - accuracy: 0.9722 - val_loss: 1.2003 - val_accuracy: 0.7751
# Epoch 21/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9664
# Epoch 21: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.1005 - accuracy: 0.9667 - val_loss: 1.2153 - val_accuracy: 0.7694
# Epoch 22/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9814
# Epoch 22: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0546 - accuracy: 0.9816 - val_loss: 0.9124 - val_accuracy: 0.8161
# Epoch 23/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9861
# Epoch 23: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 0.9757 - val_accuracy: 0.8119
# Epoch 24/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9830
# Epoch 24: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0541 - accuracy: 0.9830 - val_loss: 1.0762 - val_accuracy: 0.8006
# Epoch 25/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0729 - accuracy: 0.9793
# Epoch 25: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.0732 - accuracy: 0.9791 - val_loss: 1.4619 - val_accuracy: 0.7341
# Epoch 26/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.1497 - accuracy: 0.9561
# Epoch 26: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.1495 - accuracy: 0.9559 - val_loss: 1.3641 - val_accuracy: 0.7638
# Epoch 27/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9830
# Epoch 27: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.0550 - accuracy: 0.9828 - val_loss: 1.2478 - val_accuracy: 0.7864
# Epoch 28/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9864
# Epoch 28: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0422 - accuracy: 0.9864 - val_loss: 1.4071 - val_accuracy: 0.7921
# Epoch 29/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9805
# Epoch 29: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0557 - accuracy: 0.9803 - val_loss: 0.8685 - val_accuracy: 0.7977
# Epoch 30/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0695 - accuracy: 0.9800
# Epoch 30: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.0701 - accuracy: 0.9796 - val_loss: 1.0884 - val_accuracy: 0.8133
# Epoch 31/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0889 - accuracy: 0.9714
# Epoch 31: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0889 - accuracy: 0.9713 - val_loss: 1.5285 - val_accuracy: 0.7878
# Epoch 32/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0863 - accuracy: 0.9741
# Epoch 32: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0868 - accuracy: 0.9736 - val_loss: 1.0036 - val_accuracy: 0.7992
# Epoch 33/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9807
# Epoch 33: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 30ms/step - loss: 0.0660 - accuracy: 0.9809 - val_loss: 1.0797 - val_accuracy: 0.8091
# Epoch 34/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9743
# Epoch 34: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0856 - accuracy: 0.9745 - val_loss: 1.4101 - val_accuracy: 0.7935
# Epoch 35/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9829
# Epoch 35: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0541 - accuracy: 0.9830 - val_loss: 0.8792 - val_accuracy: 0.8133
# Epoch 36/50
# 175/177 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9864
# Epoch 36: val_loss did not improve from 0.68157
# 177/177 [==============================] - 5s 29ms/step - loss: 0.0365 - accuracy: 0.9865 - val_loss: 0.9168 - val_accuracy: 0.8161
# Epoch 36: early stopping

# %%
model.load_weights('best_model.h5')

# %%
# Performance Evaluation
test_loss, test_accuracy = model.evaluate(np.array(X_test_wav), np.array(y_test), verbose=2)
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
# Out:
# 48/48 - 1s - loss: 0.7477 - accuracy: 0.8406 - 640ms/epoch - 13ms/step
# Test loss: 0.7476516962051392
# Test accuracy: 0.8406084775924683

# %%
# Computational complexity evaluation
total_params = model.count_params()
print(f'Total parameters: {total_params}')
# Out:
# Total parameters: 3241164

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  llf_3channels_1 (LLF_3chann  (None, 198, 64, 3)       0
#  els)
#
#  MobileNet_embeddings (Mobil  (None, 1024)             3228864
#  eNetEmbeddings)
#
#  dense_3 (Dense)             (None, 12)                12300
#
#  activation_3 (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 3,241,164
# Trainable params: 3,205,260
# Non-trainable params: 35,904
# _________________________________________________________________

# %% [markdown]
# ### Visualization of the training process

# %%
# Plot the loss curves for training and validation.

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curves for training and validation.

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values)+1)

plt.figure(figsize=(8,6))
plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Save and export the model

model.save('model_nbac_mobilenet_imagenet_al2s.h5')

# %% [markdown]
# ### Confusion matrix

# %%
y_true = y_test
y_pred = model.predict(np.array(X_test_wav))
y_pred = np.argmax(y_pred, axis=1)

# Get the class names in the order corresponding to the class indices
class_names = [reversed_labels[i] for i in range(len(reversed_labels))]

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 48/48 [==============================] - 1s 12ms/step
